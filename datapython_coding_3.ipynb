# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snb
import numpy as np

# %%
g_apps = pd.read_csv(r"C:\Users\Yuceltan\data\googleplaystore.csv")

# %%
g_apps['index']=range(0,10841)

# %%
g_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'index'],
#       dtype='object')

# %%
categories = g_apps.Category.value_counts().to_frame()

# %%
categories
# Out:
#                      Category
# FAMILY                   1972
# GAME                     1144
# TOOLS                     843
# MEDICAL                   463
# BUSINESS                  460
# PRODUCTIVITY              424
# PERSONALIZATION           392
# COMMUNICATION             387
# SPORTS                    384
# LIFESTYLE                 382
# FINANCE                   366
# HEALTH_AND_FITNESS        341
# PHOTOGRAPHY               335
# SOCIAL                    295
# NEWS_AND_MAGAZINES        283
# SHOPPING                  260
# TRAVEL_AND_LOCAL          258
# DATING                    234
# BOOKS_AND_REFERENCE       231
# VIDEO_PLAYERS             175
# EDUCATION                 156
# ENTERTAINMENT             149
# MAPS_AND_NAVIGATION       137
# FOOD_AND_DRINK            127
# HOUSE_AND_HOME             88
# LIBRARIES_AND_DEMO         85
# AUTO_AND_VEHICLES          85
# WEATHER                    82
# ART_AND_DESIGN             65
# EVENTS                     64
# ...

# %%
g_apps.loc[g_apps.Category==('1.9')]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  index
# 10472       1.0.19  4.0 and up         NaN  10472

# %%
g_apps.iloc[10472,:].to_frame()
# Out:
#                                                   10472
# App             Life Made WI-Fi Touchscreen Photo Frame
# Category                                            1.9
# Rating                                             19.0
# Reviews                                            3.0M
# Size                                             1,000+
# Installs                                           Free
# Type                                                  0
# Price                                          Everyone
# Content Rating                                      NaN
# Genres                                February 11, 2018
# Last Updated                                     1.0.19
# Current Ver                                  4.0 and up
# Android Ver                                         NaN
# index                                             10472

# %%
##g_apps.iloc[10472,1]=g_apps.iloc[10472,1].shift(1)

# %%
for i in range(2,13): g_apps.iloc[10472,-i]=g_apps.iloc[10472,-i-1]

# %%
g_apps.iloc[10472,1]='COMMUNICATION'

# %%
g_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'index'],
#       dtype='object')

# %%
g_apps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
g_apps['Installs'] = g_apps['Installs'].str.replace('+', '')
g_apps['Installs'] = g_apps['Installs'].str.replace(',', '')
g_apps['Installs'] = g_apps['Installs'].apply(lambda x: 0 if x == 'Free' else x)
g_apps['Installs'] = g_apps['Installs'].astype(int)
g_apps['Price'] = g_apps['Price'].apply(lambda x: float(x.strip('$')) if x != '0' else 0)
# Out:
# C:\Users\MIQDAD\AppData\Local\Temp\ipykernel_152\756344793.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   g_apps['Installs'] = g_apps['Installs'].str.replace('+', '')

# %%
g_apps['Installs'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## top 20 installed apps another code

# %%
# intstalled_Apps=g_apps.sort_values(by=["Installs"],inplace=False,ascending=False)
# most_intstalled_Apps=intstalled_Apps.head(20)

# %%
# most_intstalled_Apps

# %%
# plt.figure(figsize=(12,6))
# snb.set_style('whitegrid')
# snb.barplot(x='App', y= 'Installs', data=most_intstalled_Apps, palette='GnBu_d')
# plt.xticks(rotation=90)
# plt.title('20 Of The Top Installed Apps on Google Play Store')

# plt.ylabel('Number of Installs')
# plt.show()

# %%
# top_10_apps = g_apps.nlargest(10, 'Installs')

# %% [markdown]
# ## top apps by installs ,type

# %%
google_installs=g_apps[["Installs","Type"]]

# %%
crosstab_IandM=pd.crosstab(google_installs.Installs,google_installs.Type)

# %%
crosstab_IandM.index=crosstab_IandM.index.astype(int)

# %%
crosstab_IandM.sort_index(ascending=False)
# Out:
# Type        Free  Paid
# Installs
# 1000000000    58     0
# 500000000     72     0
# 100000000    409     0
# 50000000     289     0
# 10000000    1249     3
# 5000000      752     0
# 1000000     1555    24
# 500000       527    12
# 100000      1079    90
# 50000        436    43
# 10000        925   129
# 5000         410    67
# 1000         759   149
# 500          290    40
# 100          623    96
# 50           171    34
# 10           316    70
# 5             70    12
# 1             46    21
# 0              4    10

# %%
crosstab_IandM
# Out:
# Type        Free  Paid
# Installs
# 0              4    10
# 1             46    21
# 5             70    12
# 10           316    70
# 50           171    34
# 100          623    96
# 500          290    40
# 1000         759   149
# 5000         410    67
# 10000        925   129
# 50000        436    43
# 100000      1079    90
# 500000       527    12
# 1000000     1555    24
# 5000000      752     0
# 10000000    1249     3
# 50000000     289     0
# 100000000    409     0
# 500000000     72     0
# 1000000000    58     0

# %%
# google_installs = g_apps[["Installs","Type"]]
# crosstab_IandM = pd.crosstab(google_installs.Installs, google_installs.Type)
# crosstab_IandM.index = crosstab_IandM.index.astype(int)
# crosstab_IandM = crosstab_IandM.sort_index(ascending=False)
# snb.catplot(data=crosstab_IandM, kind="bar", palette="Set2", height=6, aspect=1.5)
# plt.title("Google Apps Installs by Type", fontsize=16)
# plt.xlabel("Installs", fontsize=14)
# plt.ylabel("Count", fontsize=14)
# plt.show()

# %%
google_installs = g_apps[["Installs","Type"]]
crosstab_IandM = pd.crosstab(google_installs.Installs, google_installs.Type)
crosstab_IandM.index = crosstab_IandM.index.astype(int)
crosstab_IandM = crosstab_IandM.sort_index(ascending=False)
plt.figure(figsize=(10, 8))
snb.heatmap(crosstab_IandM, cmap="YlGnBu", annot=True, fmt="d", cbar=False)
plt.title("Google Apps Installs by Type", fontsize=16)
plt.xlabel("Type", fontsize=14)
plt.ylabel("Installs", fontsize=14)
plt.show()

# %%
g_apps['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
# plt.figure(figsize=(12,6))
# snb.set_style('whitegrid')
# snb.barplot(x='App', y= 'Installs', data=top_10_apps, palette='GnBu_d')
# plt.xticks(rotation=90)
# plt.title('10 Of The Top Installed Apps on Google Play Store')

# plt.ylabel('Number of Installs')
# plt.show()

# %% [markdown]
# ## categories sorted by avg installs

# %%
mean_installs_by_category = g_apps.groupby('Category')['Installs'].mean()

# %%
mean_installs_by_category_sorted = mean_installs_by_category.sort_values(ascending=False)

# %%
snb.set(style="whitegrid")
plt.figure(figsize=(10, 6))
ax = snb.barplot(x=mean_installs_by_category_sorted.values, y=mean_installs_by_category_sorted.index)
ax.set_xlabel("Average Installs")
ax.set_ylabel("Category",fontsize=22)
ax.set_title("Average Installs by Category")
plt.show()

# %% [markdown]
# # free apps and paid apps

# %%
paid_app = g_apps[g_apps["Type"] == 'Paid'] 
free_app = g_apps[g_apps["Type"] == 'Free']

# %%
pc_count = paid_app["Category"].value_counts
fc_count = free_app["Category"].value_counts

# %% [markdown]
# ## the most prevalent categories , Paid/Free apps

# %%
most_prevalent_paid = paid_app.groupby("Category")["Installs"].sum().sort_values(ascending=False).head(10)
most_prevalent_free = free_app.groupby("Category")["Installs"].sum().sort_values(ascending=False).head(10)

# %%
snb.set_style("whitegrid")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
snb.barplot(x=most_prevalent_paid.index, y=most_prevalent_paid.values, ax=ax1)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax1.set_title("Most Prevalent Paid Apps by Category")
ax1.set_xlabel("Category")
ax1.set_ylabel("Total Installs")
snb.barplot(x=most_prevalent_free.index, y=most_prevalent_free.values, ax=ax2)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
ax2.set_title("Most Prevalent Free Apps by Category")
ax2.set_xlabel("Category")
ax2.set_ylabel("Total Installs")

plt.tight_layout()
plt.show()

# %%
g_apps.groupby("Size").size()
# Out:
# Size
# 1.0M                     7
# 1.1M                    32
# 1.2M                    41
# 1.3M                    35
# 1.4M                    37
#                       ...
# 98M                     16
# 992k                     1
# 994k                     1
# 99M                     39
# Varies with device    1695
# Length: 461, dtype: int64

# %% [markdown]
# ## converting M to KB in column size

# %%
g_apps.loc[g_apps['Size'].str.endswith('M'), 'Size'] = (g_apps.loc[g_apps['Size'].str.endswith('M'), 'Size'].str[:-1].astype(float) * 1024) .astype(int)

# %%
g_apps['Size'] = g_apps['Size'].apply(lambda x: 0 if x == 'Varies with device' else x)
g_apps['Size'] = g_apps['Size'].apply(lambda x: 0 if x == 'M' else x)
g_apps['Size'] = g_apps['Size'].apply(lambda x: int(round(float(str(x).replace('k', '')), 0)))

# %%
g_apps['Size']=g_apps['Size'].astype(int)

# %% [markdown]
# ## the smallest apps

# %%
smallest_apps= g_apps.sort_values(by='Size',ascending=False).head(50)

# %%
smallest_apps.head(5)
# Out:
#                                     App Category Rating  Reviews    Size  \
# 7404                    SimCity BuildIt   FAMILY    4.5  4218587  102400
# 3973             Hungry Shark Evolution     GAME    4.5  6071542  102400
# 2299               Navi Radiography Pro  MEDICAL    4.7       11  102400
# 1793  Mini Golf King - Multiplayer Game     GAME    4.5   531458  102400
# 5865       Gangster Town: Vice District   FAMILY    4.3    65146  102400
#
#        Installs  Type  Price Content Rating      Genres      Last Updated  \
# 7404   50000000  Free   0.00   Everyone 10+  Simulation     June 19, 2018
# 3973  100000000  Free   0.00           Teen      Arcade     July 25, 2018
# 2299        500  Paid  15.99       Everyone     Medical  January 14, 2018
# 1793    5000000  Free   0.00       Everyone      Sports     July 20, 2018
# 5865   10000000  Free   0.00     Mature 17+  Simulation      May 31, 2018
#
#        Current Ver   Android Ver  index
# 7404  1.23.3.75024    4.0 and up   7404
# ...

# %%
s_paid_app = smallest_apps[smallest_apps["Type"] == 'Paid'] 
s_free_app = smallest_apps[smallest_apps["Type"] == 'Free']

# %% [markdown]
# ## from the 50 smallest apps , how mant paid? and how many free ?

# %%
len(s_paid_app)
# Out:
# 4

# %%
len(s_free_app)
# Out:
# 46

# %% [markdown]
# ## the avarege installs for the smallest (paid/free) apps

# %%
agv_free=s_free_app['Installs'].mean()

# %%
agv_free
# Out:
# 26316848.913043477

# %%
agv_paid=s_paid_app['Installs'].mean()

# %%
agv_paid
# Out:
# 525125.0

# %% [markdown]
# ## the avarege installs for each category in the smallest paid apps dataframe

# %%
Avr_installs_paidCategory = s_paid_app.groupby('Category').Installs.mean()

# %%
Avr_installs_paidCategory
# Out:
# Category
# GAME       700000.0
# MEDICAL       500.0
# Name: Installs, dtype: float64

# %% [markdown]
# ## the avarege installs for category app in the smallest free apps dataframe

# %%
Avr_installs_freeCategory=s_free_app.groupby('Category').Installs.mean()

# %%
Avr_installs_freeCategory.head(15)
# Out:
# Category
# FAMILY                2.011577e+07
# FINANCE               1.000000e+06
# GAME                  3.550038e+07
# HEALTH_AND_FITNESS    5.000000e+03
# LIBRARIES_AND_DEMO    5.000000e+04
# LIFESTYLE             1.000000e+07
# SPORTS                7.500000e+06
# TOOLS                 5.000000e+03
# Name: Installs, dtype: float64

# %% [markdown]
# ## combine free small apps and paid small apps into one dataframe

# %%
# free_paid_small_apps = pd.concat([Avr_installs_paidapps, Avr_installs_freeapps], axis=1)
# free_paid_small_apps.columns = ['Paid', 'Free']

# %%
# free_paid_small_apps.columns

# %%
# fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

# paid_apps = free_paid_small_apps.sort_values('Paid', ascending=False)
# ax1.bar(paid_apps.index, paid_apps['Paid'], color='blue')
# ax1.set_xticklabels(labels=paid_apps.index, rotation=90)
# ax1.set_title("Average Installs - Paid Apps")
# ax1.set_ylabel("Average Installs")

# free_apps = free_paid_small_apps.sort_values('Free', ascending=False)
# ax2.bar(free_apps.index, free_apps['Free'], color='green')
# ax2.set_xticklabels(labels=free_apps.index, rotation=90)
# ax2.set_title("Average Installs - Free Apps")
# ax2.set_ylabel("Average Installs")

# ax1.tick_params(axis='x', labelsize=8)
# ax2.tick_params(axis='x', labelsize=8)

# plt.tight_layout()

# plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20,10))

sorted_free_category = Avr_installs_freeCategory.sort_values(ascending=False)
sorted_paid_category = Avr_installs_paidCategory.sort_values(ascending=False)

snb.barplot(x=sorted_free_category.index , y=sorted_free_category.values, ax=ax1, palette='Blues_d')
ax1.set_xticklabels(labels=sorted_free_category.index, rotation=90, fontsize=14, fontweight='bold')
ax1.set_title("Average Installs - free Category", fontsize=12, fontweight='bold')
ax1.set_ylabel("Average Installs", fontsize=10, fontweight='bold')
ax1.set_xlabel("")

snb.barplot(x=sorted_paid_category.index, y=sorted_paid_category.values, ax=ax2, palette='Greens_d')
ax2.set_xticklabels(labels=sorted_paid_category.index, rotation=90, fontsize=10, fontweight='bold')
ax2.set_title("Average Installs - paid Category", fontsize=14, fontweight='bold')
ax2.set_ylabel("Average Installs", fontsize=10, fontweight='bold')
ax2.set_xlabel("")

fig.tight_layout()
plt.show()

# %%
# fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20,10))

# snb.barplot(x=Avr_installs_freeCategory.index , y=Avr_installs_freeCategory.values, ax=ax1, palette='Blues_d')
# ax1.set_xticklabels(labels=Avr_installs_freeCategory.index, rotation=90, fontsize=14, fontweight='bold')
# ax1.set_title("Average Installs - free Category", fontsize=12, fontweight='bold')
# ax1.set_ylabel("Average Installs", fontsize=10, fontweight='bold')
# ax1.set_xlabel("")

# snb.barplot(x=Avr_installs_paidCategory.index, y=Avr_installs_paidCategory.values, ax=ax2, palette='Greens_d')
# ax2.set_xticklabels(labels=Avr_installs_paidCategory.index, rotation=90, fontsize=10, fontweight='bold')
# ax2.set_title("Average Installs - paid Category", fontsize=14, fontweight='bold')
# ax2.set_ylabel("Average Installs", fontsize=10, fontweight='bold')
# ax2.set_xlabel("")

# fig.tight_layout()
# plt.show()

# %% [markdown]
# ## the success depends on the high rate and the huge amount of installs

# %%
def success_metric(rating, installs):
    return rating * np.log(installs)

# %%
smallest_apps['Success'] = success_metric(smallest_apps['Rating'], smallest_apps['Installs'])

# %%
top_10 = smallest_apps.sort_values(by='Success', ascending=True).head(10)

# %%
top_10.groupby(by= 'Category').size()
# Out:
# Category
# FAMILY                2
# GAME                  4
# HEALTH_AND_FITNESS    1
# LIBRARIES_AND_DEMO    1
# MEDICAL               1
# TOOLS                 1
# dtype: int64

# %%
top_10.groupby(by= 'Type').size()
# Out:
# Type
# Free    8
# Paid    2
# dtype: int64

# %%
# plt.figure(figsize=(10, 8))
# snb.barplot(data=top_10, x='Category', y='Success', estimator=len, palette='Blues')
# plt.title("Top 10 Apps by Category", fontsize=16)
# plt.xlabel("Category", fontsize=14)
# plt.ylabel("Count", fontsize=14)
# snb.barplot(data=top_10, x='Category', y='Success', hue='Type', palette='Set2', alpha=0.8)
# plt.title("Top 10 Apps by Category and Type", fontsize=16)
# plt.xlabel("Category", fontsize=14)
# plt.ylabel("Success Metric", fontsize=14)

# plt.show()

# %%
pivot_table = pd.pivot_table(data=top_10, index='Category', columns='Type', values='Success', aggfunc=len)


snb.heatmap(data=pivot_table, cmap='Blues', annot=True, fmt='g', cbar=False ,vmin=0.4, linecolor='black', linewidths=1)
plt.title("Top 10 Successed  Apps by Category and Type", fontsize=16)
plt.xlabel("Type", fontsize=14)
plt.ylabel("Category", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = snb.barplot(x='Success', y='App', data=top_10, palette='Blues_d')
ax.set_title('Top 10 Most Successful Small Apps')
ax.set_xlabel('Success Metric')
ax.set_ylabel('App Name')
plt.show()

# %%
g_apps['Price'] = pd.to_numeric(g_apps['Price'])

# %%
g_apps.dtypes
# Out:
# App                object
# Category           object
# Rating             object
# Reviews            object
# Size                int32
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# index               int64
# dtype: object

# %%
g_apps['Price']=g_apps['Price'].astype(int)

# %% [markdown]
# ## calculating the revenue for the smallest apps

# %%
s_paid_app['Revenue'] = s_paid_app['Price'] * s_paid_app['Installs']
# Out:
# C:\Users\MIQDAD\AppData\Local\Temp\ipykernel_152\1110647416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s_paid_app['Revenue'] = s_paid_app['Price'] * s_paid_app['Installs']

# %%
top_revenue_apps = s_paid_app.sort_values(by=["Revenue"], ascending=False)

top_revenue_apps['Category'].value_counts()
# Out:
# GAME       3
# MEDICAL    1
# Name: Category, dtype: int64

# %%
top_revenue_apps
# Out:
#                                                     App Category Rating  \
# 9170                      Stickman Legends: Shadow Wars     GAME    4.4
# 9165  League of Stickman 2018- Ninja Arena PVP(Dream...     GAME    4.4
# 5641                        Five Nights at Freddy's: SL     GAME    4.5
# 2299                               Navi Radiography Pro  MEDICAL    4.7
#
#      Reviews    Size  Installs  Type  Price Content Rating   Genres  \
# 9170   38419  102400   1000000  Paid   0.99   Everyone 10+   Action
# 9165   32496  101376   1000000  Paid   0.99           Teen   Action
# 5641   16162  101376    100000  Paid   2.99           Teen   Action
# 2299      11  102400       500  Paid  15.99       Everyone  Medical
#
#           Last Updated Current Ver   Android Ver  index   Revenue
# 9170    August 3, 2018      2.3.24    4.1 and up   9170  990000.0
# 9165      July 3, 2018       5.3.3    2.3 and up   9165  990000.0
# ...

# %%
snb.countplot(data=top_revenue_apps, y='Category', palette='Blues_r', 
              order=top_revenue_apps['Category'].value_counts().index, )
plt.title('Top  revenue apps by category', fontsize=18)
plt.xlabel('Number of Apps', fontsize=14)
plt.ylabel('Category', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
g_apps['Size'] = g_apps['Size'].apply(lambda x: 0 if x == 'Varies with device' else x)
g_apps['Size'] = g_apps['Size'].apply(lambda x: 0 if x == 'M' else x)
g_apps['Size'] = g_apps['Size'].apply(lambda x: int(round(float(str(x).replace('k', '')), 0)))

# %%
g_apps['Size']= pd.to_numeric(g_apps['Size'])

# %%
revenue_mean_size = top_revenue_apps["Size"].mean()

# %%
revenue_mean_size
# Out:
# 101888.0

# %%
top_revenue_apps.dtypes
# Out:
# App                object
# Category           object
# Rating             object
# Reviews            object
# Size                int32
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# index               int64
# Revenue           float64
# dtype: object

# %% [markdown]
# ## comparing categories by rating and reviews

# %%
lolly = pd.read_csv(r"C:\Users\MIQDAD\data\googleplaystore_user_reviews.csv")

# %%
lolly.dropna(subset=['Translated_Review', 'Sentiment' ], inplace=True)

# %%
df_apps = g_apps[['App', 'Category', 'Rating' , 'Type']]

# %%
lolly= lolly[['App','Sentiment','Sentiment_Polarity','Sentiment_Subjectivity']]

# %%
merged_df = pd.merge(lolly, df_apps, on='App', how='left')

# %%
positive_cat = merged_df[merged_df["Sentiment"] == 'Positive'] 
count_pos = positive_cat["Category"].value_counts()

# %%
nagative_cat = merged_df[merged_df["Sentiment"] == 'Negative'] 
count_neg = nagative_cat["Category"].value_counts()

# %%
neutral_cat = merged_df[merged_df["Sentiment"] == 'Neutral'] 
count_neu = neutral_cat["Category"].value_counts()

# %%
sentiment_counts = pd.concat([count_pos, count_neg, count_neu], axis=1)
sentiment_counts.columns = ['Positive', 'Negative', 'Neutral']
sentiment_counts = sentiment_counts.fillna(0)

# %%
# snb.set(style="whitegrid")
# snb.set_palette("bright")
# plt.figure(figsize=(12, 8))
# ax = snb.barplot(x=sentiment_counts.index, y="Positive", data=sentiment_counts, label="Positive")
# ax = snb.barplot(x=sentiment_counts.index, y="Negative", data=sentiment_counts, label="Negative")
# ax = snb.barplot(x=sentiment_counts.index, y="Neutral", data=sentiment_counts, label="Neutral")
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right', fontsize='large')
# ax.set_xlabel('Category')
# ax.set_ylabel('Number of Reviews')
# ax.set_title('Sentiment Distribution by Category')
# plt.legend()
# plt.show()

# %%
snb.set(style="whitegrid")
snb.set_palette(snb.color_palette(["#4CAF50", "#F44336", "#FFC107"])) 
plt.figure(figsize=(18, 12))
ax = snb.barplot(x=sentiment_counts.index, y="Positive", data=sentiment_counts, palette=snb.color_palette(["#4CAF50"]), label="Positive")
ax = snb.barplot(x=sentiment_counts.index, y="Negative", data=sentiment_counts, palette=snb.color_palette(["#F44336"]), label="Negative")
ax = snb.barplot(x=sentiment_counts.index, y="Neutral", data=sentiment_counts, palette=snb.color_palette(["#FFC107"]), label="Neutral")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.set_xlabel('Category',fontsize='large')
ax.set_ylabel('Number of Reviews',fontsize='large')
ax.set_title('Sentiment Distribution by Category',fontsize='large')
ax.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()

# %%
a = merged_df.groupby('Type')['Rating'].describe()

# %%
a
# Out:
#         count  unique  top     freq
# Type
# Free  71784.0    22.0  4.4  12026.0
# Paid    782.0     6.0  4.4    216.0
